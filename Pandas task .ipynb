# %% [markdown]
# ## 05/03/2022 Task

# %% [markdown]
# ## Task 1

# %% [markdown]
#     Problem statement:
#     1.how many campaign available in this dataset.
#     2.how many users do we have with housing and personal loan.
#     3.how many person do we have whose age is 60plus
#     4.in which month we have targeted most of the customer.
#     5.which mode of call is giving you more result
#     6.how many enterprenuers do we have in this list
#     7.how many customers do we have with negative balance.
#     8.prepare a group of data based on education level

# %%
import pandas as pd
data=pd.read_csv('bank.csv',sep=';')

# %%
data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ### 1.how many campaign available in this dataset.

# %%
total_campaign=data['campaign'].unique()

# %%
total_campaign
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44],
#       dtype=int64)

# %% [markdown]
# ### 2.how many users do we have with housing and personal loan.

# %%
# housing loan
housing_loan=(data[data['housing']=='yes'])

# %%
housing_loan['housing'].count()
# housing loan users =2559
# Out:
# 2559

# %%
# personal loan
users_persnal_loan=(data[data['loan']=='yes'])

# %%
users_persnal_loan['loan'].count()
# personal loan users=691
# Out:
# 691

# %% [markdown]
# ### 3.how many person do we have whose age is 60plus

# %%
age_gt_sixty=(data[data['age']>60])

# %%
age_gt_sixty
# Out:
#       age         job   marital  education default  balance housing loan  \
# 27     67     retired   married    unknown      no      696      no   no
# 30     68     retired  divorced  secondary      no     4189      no   no
# 36     78     retired  divorced    primary      no      229      no   no
# 49     61      admin.   married    unknown      no     4629     yes   no
# 61     63     retired   married  secondary      no      415     yes   no
# ...   ...         ...       ...        ...     ...      ...     ...  ...
# 4337   73     retired   married    unknown      no      519      no   no
# 4364   63     retired  divorced  secondary      no     1490      no   no
# 4388   83     retired  divorced    primary      no     1097      no   no
# 4413   65     retired   married    primary      no      493      no   no
# 4466   61  management   married  secondary      no      967      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
age_gt_sixty['age'].count()
# Age greater than 60 , retired persons are equal to 127
# Out:
# 127

# %% [markdown]
# ### 4.In which month we have targeted most of the customer.

# %%
data['month'].describe()
# may month was the top month
# Out:
# count     4521
# unique      12
# top        may
# freq      1398
# Name: month, dtype: object

# %%
d=data[data['month']=='may']

# %%
d['month'].count()
# total 1398 customers are subscribed on this month
# Out:
# 1398

# %%
data['month'].unique()
# Out:
# array(['oct', 'may', 'apr', 'jun', 'feb', 'aug', 'jan', 'jul', 'nov',
#        'sep', 'mar', 'dec'], dtype=object)

# %% [markdown]
# ### 5.which mode of call is giving you more result

# %%
callmode=(data[data['contact']=='cellular'])

# %%
callmode[callmode['y']=='yes']
# Out:
#       age            job  marital  education default  balance housing loan  \
# 13     20        student   single  secondary      no      502      no   no
# 33     32     management   single   tertiary      no     2536     yes   no
# 34     49     technician  married   tertiary      no     1235      no   no
# 37     32    blue-collar  married  secondary      no     2089     yes   no
# 38     33     management  married  secondary      no     3935     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4458   29     management   single   tertiary      no      572      no   no
# 4465   38     management   single   tertiary      no      623      no   no
# 4484   38     management  married   tertiary      no     3436      no   no
# 4503   60  self-employed  married    primary      no      362      no  yes
# 4504   42    blue-collar   single  secondary      no     1080     yes  yes
#
# ...

# %%
cellular_count=callmode[callmode['y']=='yes']
cellular_count['contact'].count()
# total count of cellular phone 416 so compare to telephone cellular phone gave good result
# Out:
# 416

# %%
callmode_telephone=(data[data['contact']=='telephone'])

# %%
(callmode_telephone[callmode_telephone['y']=='yes'])
# Out:
#       age           job   marital  education default  balance housing loan  \
# 30     68       retired  divorced  secondary      no     4189      no   no
# 36     78       retired  divorced    primary      no      229      no   no
# 83     52      services   married  secondary      no      657      no   no
# 114    25       student    single  secondary      no      331      no   no
# 199    75       retired   married  secondary      no     3771      no   no
# 204    29   blue-collar    single   tertiary      no      455      no   no
# 382    59       retired   married   tertiary      no     9676      no   no
# 443    30    management   married   tertiary      no     1221     yes   no
# 477    77       retired   married   tertiary      no     7802      no   no
# 492    53        admin.   married  secondary      no     1796      no   no
# 1025   56       retired   married  secondary      no     1044      no   no
# ...

# %%
count_telephone=(callmode_telephone[callmode_telephone['y']=='yes'])

# %%
count_telephone['contact'].count()
# count of telephone is 44
# Out:
# 44

# %%
data.head(20)
# Out:
#     age            job  marital  education default  balance housing loan  \
# 0    30     unemployed  married    primary      no     1787      no   no
# 1    33       services  married  secondary      no     4789     yes  yes
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
# 9    43       services  married    primary      no      -88     yes  yes
# 10   39       services  married  secondary      no     9374     yes   no
# 11   43         admin.  married  secondary      no      264     yes   no
# ...

# %% [markdown]
# ### 6.how many enterprenuers do we have in this list

# %%
no_of_entrepreneur=data[data['job']=='entrepreneur']

# %%
no_of_entrepreneur['job'].count()
#total no of emtrepreneur is 168
# Out:
# 168

# %% [markdown]
# ### 7.how many customers do we have with negative balance.

# %%
minus_balance=(data[data['balance']<0])

# %%
minus_balance['balance'].count()
# no of minus balance account is 366
# Out:
# 366

# %% [markdown]
# ### 8.Prepare a group of data based on education level

# %%
Education=data.groupby(["education"]).first()

# %%
Education
# Out:
#            age         job   marital default  balance housing loan   contact  \
# education
# primary     30  unemployed   married      no     1787      no   no  cellular
# secondary   33    services   married      no     4789     yes  yes  cellular
# tertiary    35  management    single      no     1350     yes   no  cellular
# unknown     38  management  divorced      no        0     yes   no  cellular
#
#            day month  duration  campaign  pdays  previous poutcome   y
# education
# primary     19   oct        79         1     -1         0  unknown  no
# secondary   11   may       220         1    339         4  failure  no
# tertiary    16   apr       185         1    330         1  failure  no
# unknown     18   nov        96         2     -1         0  unknown  no

# %%
data.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# ## Task 2

# %%
data1=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
#
#     1.find out how many male and female pssengers was onboarded
#     2.how many survied we have
#     3.how many casuality we have
#     4.what is the name of the personhow is eldest
#     5.how many passengers do we have in first, second, third class
#     6.how many person we have whose name start with 's'
#     7.try to create a new column which is a summation of 'sibsp' and 'parch'
#     8.how many person do we have belo age of 25
#     9.how many person died whose age was less then 40
#     10.from a cabin column seperste text and numeric values

# %% [markdown]
# ### 1.Find out how many male and female pssengers was onboarded

# %%
male=(data1[data1['Sex']=='male'])
female=(data1[data1['Sex']=='female'])

# %%
male['Sex'].count()
#total male count=577
# Out:
# 577

# %%
female['Sex'].count()
#total female count=314
# Out:
# 314

# %% [markdown]
# ### 2.how many survied we have

# %%
survived=data1[data1['Survived']==1]
survived['Survived'].count()
#total survived persons=342
# Out:
# 342

# %% [markdown]
# ### 3.how many casuality we have

# %%
casuality=data1[data1['Survived']==0]
casuality['Survived'].count()
#total casuality persons=549
# Out:
# 549

# %% [markdown]
# ### 4 . what is name of a person who is the eldest one

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
min_age=data1['Age'].min()

# %%
min_age
# Out:
# 0.42

# %%
data1[data1['Age']==0.42]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
data1[data1['Age']==min(data1['Age'])]['Name']
# Out:
# 803    Thomas, Master. Assad Alexander
# Name: Name, dtype: object

# %% [markdown]
# ### 5.how many passengers do we have in first, second, third class

# %%
passengers=data1.groupby(['Pclass',"Name"]).first()

# %%
passengers
# Out:
#                                                         PassengerId  Survived  \
# Pclass Name
# 1      Allen, Miss. Elisabeth Walton                            731         1
#        Allison, Master. Hudson Trevor                           306         1
#        Allison, Miss. Helen Loraine                             298         0
#        Allison, Mrs. Hudson J C (Bessie Waldo Daniels)          499         0
#        Anderson, Mr. Harry                                      461         1
# ...                                                             ...       ...
# 3      de Messemaeker, Mrs. Guillaume Joseph (Emma)             560         1
#        de Mulder, Mr. Theodore                                  287         1
#        de Pelsmaeker, Mr. Alfons                                283         0
#        van Billiard, Mr. Austin Blyler                          154         0
#        van Melkebeke, Mr. Philemon                              869         0
#
# ...

# %%
first_class=data1[data1['Pclass']==1]
first_class['Pclass'].count()
# Out:
# 216

# %%
second_class=data1[data1['Pclass']==2]
second_class['Pclass'].count()
# Out:
# 184

# %%
third_class=data1[data1['Pclass']==3]
third_class['Pclass'].count()
# Out:
# 491

# %% [markdown]
# ### 6.how many person we have whose name start with 's'

# %%
name=data1[data1['Name'].str.startswith('S')]

# %%
name['Name']
# Out:
# 10                       Sandstrom, Miss. Marguerite Rut
# 12                        Saundercock, Mr. William Henry
# 23                          Sloper, Mr. William Thompson
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# 48                                   Samaan, Mr. Youssef
#                              ...
# 851                                  Svensson, Mr. Johan
# 862    Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 863                    Sage, Miss. Dorothy Edith "Dolly"
# 880         Shelley, Mrs. William (Imanita Parrish Hall)
# 884                               Sutehall, Mr. Henry Jr
# Name: Name, Length: 86, dtype: object

# %% [markdown]
# ### 7.try to create a new column which is a summation of 'sibsp' and 'parch'

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1['sum']=data1['SibSp']+data1['Parch']

# %%
data1['sum']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Name: sum, Length: 891, dtype: int64

# %% [markdown]
# ### 8.how many person do we have below age of 25

# %%
Person_below25=data1[data1['Age']<25]

# %%
Person_below25['Age'].count()
# Out:
# 278

# %% [markdown]
# ### 9.how many person died whose age was less then 40

# %%
Person_died=data1[data1['Age']<40]

# %%
count=Person_died[Person_died['Survived']==0]

# %%
count['Survived'].count()
# Out:
# 322

# %% [markdown]
# ### 10.from a cabin column seperste text and numeric values

# %%
data1['series1'] = data1['Cabin'].str.extract('(\w)', expand=True)
data1['seriesnum'] = data1['Cabin'].str.extract('(\d)', expand=True)

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
